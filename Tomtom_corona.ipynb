# %%
import numpy as np 
# library to load dataframe
import pandas as pd

# Matplotlib and associated plotting modules
import matplotlib.colors as colors
import matplotlib.pyplot as plt

# %%
import requests

# %%
import folium

# %%
tomtom_api_keys = ["tU9o5dk12G77CPrTKtELyzBLNGPcaOBh"] # 2500 free calls/day
api_key = tomtom_api_keys[0]

# %%
tomtom_api_keys
# Out:
# ['tU9o5dk12G77CPrTKtELyzBLNGPcaOBh']

# %%
# Search for city:
def SearchCity(api_key,City,Country):
    
    url = 'https://api.tomtom.com/search/2/search/'
    url += City + ', ' + Country
    url += '.json?limit=1&idxSet=Geo&key=' + api_key
    
    result = requests.get(url).json()
    #print(result)
    GeoID = result['results'][0]['dataSources']['geometry']['id']
    position = result['results'][0]['position']
    
    return GeoID,position

# %% [markdown]
# Fuzzy Search
# ```
# curl 'https://<baseURL>/search/<versionNumber>/search/<query>.<ext>?key=<Your_API_Key>[&typeahead=<typeahead>][&limit=<limit>][&ofs=<ofs>][&countrySet=<countrySet>][&lat=<lat>][&lon=<lon>][&radius=<radius>][&topLeft=<topLeft>][&btmRight=<btmRight>][&language=<language>][&idxSet=<idxSet>][&extendedPostalCodesFor=<extendedPostalCodesFor>][&minFuzzyLevel=<minFuzzyLevel>][&maxFuzzyLevel=<maxFuzzyLevel>][&view=<view>][&openingHours=<openingHours>][&timeZone=<timeZone>][&mapcodes=<mapcodes>]'
# ```

# %%
wuhan_position = SearchCity(api_key, "Hubei", "China")

# %%
def cityLocation(city, country):
    assert isinstance(city,str) & isinstance(country,str), 'cityName and countryName should be string' 
    city_position = SearchCity(api_key, city, country)
    lat_city = city_position[1]['lat']
    lon_city = city_position[1]['lon']
    #print("Center of Wuhan lat/lon: (", lat_city, lon_city, ")")
    return lat_city, lon_city

# %%
def init_map(api_key=api_key, latitude=0, longitude=0, zoom=14, layer = "basic", style = "main"):
    """
    The initialise_map function initializes a clean TomTom map
    """
    
    maps_url = "http://{s}.api.tomtom.com/map/1/tile/"+layer+"/"+style+"/{z}/{x}/{y}.png?tileSize=512&key="
    TomTom_map = folium.Map(
        location = [latitude, longitude],  # on what coordinates [lat, lon] initialise the map
        zoom_start = zoom,  # with what zoom level to initialize the map, from 0 to 22
        tiles = str(maps_url + api_key),
        attr = 'TomTom')
    
    return TomTom_map

# %%
df_corona = pd.read_csv('2-4csv.csv', sep=';')

# %%
df_corona
# Out:
#      1   Province/State  Country/Region   Last Update  Confirmed  Deaths  \
# 0    2            Hubei  Mainland China  2/4/20 23:43      16678     479
# 1    3         Zhejiang  Mainland China   2/5/20 1:33        895       0
# 2    4        Guangdong  Mainland China   2/5/20 2:03        870       0
# 3    5            Henan  Mainland China   2/5/20 1:13        764       2
# 4    6            Hunan  Mainland China   2/5/20 1:43        661       0
# ..  ..              ...             ...           ...        ...     ...
# 65  67       Boston, MA              US  2/1/20 19:43          1       0
# 66  68  Los Angeles, CA              US  2/1/20 19:53          1       0
# 67  69       Orange, CA              US  2/1/20 19:53          1       0
# 68  70      Seattle, WA              US  2/1/20 19:43          1       0
# 69  71        Tempe, AZ              US  2/1/20 19:43          1       0
#
#     Recovered
# 0         522
# 1          63
# 2          32
# 3          41
# 4          35
# ..        ...
# 65          0
# 66          0
# 67          0
# 68          0
# 69          0
#
# [70 rows x 7 columns]

# %%
df_china = df_corona.loc[df_corona['Country/Region'] == 'Mainland China']
df_china
# Out:
#      1  Province/State  Country/Region   Last Update  Confirmed  Deaths  \
# 0    2           Hubei  Mainland China  2/4/20 23:43      16678     479
# 1    3        Zhejiang  Mainland China   2/5/20 1:33        895       0
# 2    4       Guangdong  Mainland China   2/5/20 2:03        870       0
# 3    5           Henan  Mainland China   2/5/20 1:13        764       2
# 4    6           Hunan  Mainland China   2/5/20 1:43        661       0
# 5    7         Jiangxi  Mainland China   2/5/20 1:33        548       0
# 6    8           Anhui  Mainland China   2/5/20 1:13        530       0
# 7    9       Chongqing  Mainland China   2/5/20 0:13        366       2
# 8   10         Jiangsu  Mainland China   2/5/20 2:43        341       0
# 9   11         Sichuan  Mainland China   2/5/20 0:53        301       1
# 10  12        Shandong  Mainland China   2/5/20 1:03        298       0
# 11  13        Shanghai  Mainland China   2/5/20 0:23        233       1
# 12  14         Beijing  Mainland China   2/4/20 8:33        228       1
# 13  15          Fujian  Mainland China  2/4/20 12:13        194       0
# 14  16    Heilongjiang  Mainland China   2/5/20 1:23        190       2
# 15  17         Shaanxi  Mainland China   2/5/20 2:43        165       0
# 16  18         Guangxi  Mainland China   2/5/20 0:43        150       0
# 17  19           Hebei  Mainland China   2/5/20 2:53        135       1
# 18  20          Yunnan  Mainland China  2/4/20 23:23        122       0
# 19  21          Hainan  Mainland China   2/5/20 2:53         91       1
# 20  22        Liaoning  Mainland China  2/4/20 14:13         81       0
# 21  23          Shanxi  Mainland China  2/4/20 23:23         81       0
# 22  24         Tianjin  Mainland China  2/4/20 13:33         67       0
# 23  25         Guizhou  Mainland China   2/5/20 1:23         64       0
# 24  26           Gansu  Mainland China  2/4/20 15:43         57       0
# 25  27           Jilin  Mainland China   2/5/20 0:43         54       0
# 26  28  Inner Mongolia  Mainland China   2/5/20 1:53         42       0
# 27  29         Ningxia  Mainland China   2/4/20 2:13         34       0
# 28  30        Xinjiang  Mainland China   2/5/20 2:03         32       0
# 33  35         Qinghai  Mainland China   2/5/20 1:23         17       0
# 60  62           Tibet  Mainland China   2/1/20 1:52          1       0
#
#     Recovered
# 0         522
# 1          63
# 2          32
# 3          41
# 4          35
# 5          27
# 6          20
# 7          14
# 8          13
# 9          23
# 10         13
# 11         12
# 12         23
# 13          3
# 14          4
# 15          2
# 16         10
# 17          4
# 18          5
# 19          4
# 20          2
# 21          4
# 22          2
# 23          5
# 24          4
# 25          1
# 26          1
# 27          1
# 28          0
# 33          0
# 60          0

# %%
city_series = df_china['Province/State'].to_list()

# %%
len(city_series)
# Out:
# 31

# %%
def queryGeo(city_series, country):
    lon_list = []
    lat_list = []
    for cityName in city_series:
        try:
            latlon = cityLocation(cityName, country)
        except (NameError,JSONDecodeError):
            pass
        print(latlon)
        lat_list.append(latlon[0])
        lon_list.append(latlon[1])
    return lat_list, lon_list

# %%
cityLocation('Jiangxi', 'china')
# Out:
# (27.28597, 116.01609)

# %%
latlon_series = queryGeo(city_series, 'china')
# Out:
# (31.16063, 112.24886)
# (29.17154, 120.06824)
# (22.87085, 113.41972)
# (33.87541, 113.48402)
# (27.3818, 111.51068)
# (27.28597, 116.01609)
# (32.02638, 117.25275)
# (29.56692, 106.59304)
# (32.93708, 119.15193)
# (30.14208, 102.96496)
# (36.32902, 118.76988)
# (31.2184, 121.43456)
# (39.93084, 116.38634)
# (25.94205, 118.13727)
# (48.49496, 127.9781)
# (35.6452, 108.47221)
# (23.89393, 108.26651)
# (39.33721, 116.64286)
# (25.18113, 101.86414)
# (19.1604, 109.82704)
# (41.09748, 122.31478)
# (37.66119, 112.38998)
# (39.13197, 117.19807)
# (26.92847, 106.55943)
# (37.68319, 101.10082)
# (43.57689, 126.4792)
# (45.37661, 111.69734)
# (37.31424, 105.9722)
# (42.17386, 84.94479)
# (35.48333, 96.25259)
# (31.9032, 88.7527)

# %%
latarray= np.asarray(latlon_series[0])
lonarray = np.asarray(latlon_series[1])

# %%
latarray
# Out:
# array([31.16063, 29.17154, 22.87085, 33.87541, 27.3818 , 27.28597,
#        32.02638, 29.56692, 32.93708, 30.14208, 36.32902, 31.2184 ,
#        39.93084, 25.94205, 48.49496, 35.6452 , 23.89393, 39.33721,
#        25.18113, 19.1604 , 41.09748, 37.66119, 39.13197, 26.92847,
#        37.68319, 43.57689, 45.37661, 37.31424, 42.17386, 35.48333,
#        31.9032 ])

# %%
df_lat = pd.DataFrame(latarray, columns=['lat'])

# %%
df_lon = pd.DataFrame(lonarray, columns=['lon'])

# %%
df_china
# Out:
#      1  Province/State  Country/Region   Last Update  Confirmed  Deaths  \
# 0    2           Hubei  Mainland China  2/4/20 23:43      16678     479
# 1    3        Zhejiang  Mainland China   2/5/20 1:33        895       0
# 2    4       Guangdong  Mainland China   2/5/20 2:03        870       0
# 3    5           Henan  Mainland China   2/5/20 1:13        764       2
# 4    6           Hunan  Mainland China   2/5/20 1:43        661       0
# 5    7         Jiangxi  Mainland China   2/5/20 1:33        548       0
# 6    8           Anhui  Mainland China   2/5/20 1:13        530       0
# 7    9       Chongqing  Mainland China   2/5/20 0:13        366       2
# 8   10         Jiangsu  Mainland China   2/5/20 2:43        341       0
# 9   11         Sichuan  Mainland China   2/5/20 0:53        301       1
# 10  12        Shandong  Mainland China   2/5/20 1:03        298       0
# 11  13        Shanghai  Mainland China   2/5/20 0:23        233       1
# 12  14         Beijing  Mainland China   2/4/20 8:33        228       1
# 13  15          Fujian  Mainland China  2/4/20 12:13        194       0
# 14  16    Heilongjiang  Mainland China   2/5/20 1:23        190       2
# 15  17         Shaanxi  Mainland China   2/5/20 2:43        165       0
# 16  18         Guangxi  Mainland China   2/5/20 0:43        150       0
# 17  19           Hebei  Mainland China   2/5/20 2:53        135       1
# 18  20          Yunnan  Mainland China  2/4/20 23:23        122       0
# 19  21          Hainan  Mainland China   2/5/20 2:53         91       1
# 20  22        Liaoning  Mainland China  2/4/20 14:13         81       0
# 21  23          Shanxi  Mainland China  2/4/20 23:23         81       0
# 22  24         Tianjin  Mainland China  2/4/20 13:33         67       0
# 23  25         Guizhou  Mainland China   2/5/20 1:23         64       0
# 24  26           Gansu  Mainland China  2/4/20 15:43         57       0
# 25  27           Jilin  Mainland China   2/5/20 0:43         54       0
# 26  28  Inner Mongolia  Mainland China   2/5/20 1:53         42       0
# 27  29         Ningxia  Mainland China   2/4/20 2:13         34       0
# 28  30        Xinjiang  Mainland China   2/5/20 2:03         32       0
# 33  35         Qinghai  Mainland China   2/5/20 1:23         17       0
# 60  62           Tibet  Mainland China   2/1/20 1:52          1       0
#
#     Recovered
# 0         522
# 1          63
# 2          32
# 3          41
# 4          35
# 5          27
# 6          20
# 7          14
# 8          13
# 9          23
# 10         13
# 11         12
# 12         23
# 13          3
# 14          4
# 15          2
# 16         10
# 17          4
# 18          5
# 19          4
# 20          2
# 21          4
# 22          2
# 23          5
# 24          4
# 25          1
# 26          1
# 27          1
# 28          0
# 33          0
# 60          0

# %%
df_china1 = df_china.reset_index()[['Province/State', 'Country/Region', 'Last Update', 'Confirmed', 'Deaths','Recovered']]

# %%
df_china1 = pd.concat([df_china1, df_lat, df_lon], axis=1)

# %%
df_china1.to_csv('/Users/hao/Documents/GitHub/cy20200204/china_latlon.csv', sep=';')

# %%
TomTom_map = init_map(latitude=lat_wuhan, longitude=lon_wuhan, zoom=5, layer = "hybrid")

#add markers to map
for lat, lon, con, rec, dea in zip(df_china1['lat'], df_china1['lon'], df_china1['Confirmed'],df_china1['Recovered'], df_china1['Deaths']):
    label = 'Confirmed:{}\nRecovered:{}\nDeath:{} '.format(con, rec, dea)
    label = folium.Popup(label, parse_html=True)
    folium.Circle(
        [lat, lon],
        radius=con/20000,
        popup=label, 
        color='#FF7F0F', # Orange
        fill=True,
        fill_color='#FF7F0F',
        fill_opacity=0.3).add_to(TomTom_map)

# %%
TomTom_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print ('Confirmed:{}\nRecovered:{} '.format(1, 2))
# Out:
# Confirmed:1
# Recovered:2
